# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
images = glob.glob('../../Downloads/train_images/*') # write the address here of the images

print(len(images))

print(images[0:10])
print(type(images[0]))
# Out:
# 51033
# ['../../Downloads/train_images\\00021adfb725ed.jpg', '../../Downloads/train_images\\000562241d384d.jpg', '../../Downloads/train_images\\0007c33415ce37.jpg', '../../Downloads/train_images\\0007d9bca26a99.jpg', '../../Downloads/train_images\\00087baf5cef7a.jpg', '../../Downloads/train_images\\000a8f2d5c316a.jpg', '../../Downloads/train_images\\000be9acf46619.jpg', '../../Downloads/train_images\\000bef247c7a42.jpg', '../../Downloads/train_images\\000c3d63069748.jpg', '../../Downloads/train_images\\000c476c11bad5.jpg']
# <class 'str'>

# %%
print(images[0][29:])
# Out:
# 00021adfb725ed.jpg

# %%
images_train = []
for x in range(200):
    images_train.append(cv2.imread(images[x]))

# %%
images_train = np.array(images_train, dtype=object)
print(np.shape(images_train))
# Out:
# (200,)

# %%
#scale_percent = 60 # percent of original size
#width = int(img.shape[1] * scale_percent / 100)
#height = int(img.shape[0] * scale_percent / 100)

width = 256
height = 256

dim = (width, height)
  
# resize image
resized = []
for x in range(100):
    resized.append(cv2.resize(images_train[x], dim, interpolation = cv2.INTER_AREA))

#cv2.imshow("Resized image", resized[0])
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# Plot results
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 10),
                                    sharex=True, sharey=True)
ax1.imshow(images_train[1], cmap='gray')
ax1.axis('off')
ax1.set_title('Original')
ax2.imshow(resized[1], cmap='magma')
ax2.axis('off')
ax2.set_title('Resized')

fig.tight_layout()
plt.show()

# %%
plt.imshow(images_train[10])

# %%
plt.imshow(resized[10])

# %%
#cv2.imwrite('./256x256_Berkley_Images/1.png', resized[0])
#stringLoc = './256x256_Berkley_Images' + str(i) + '.png'
#print(stringLoc)

for i in range(len(resized)):
    stringLoc = './256x256_NormalizedWhaleImages/' + images[i][29:] 
    cv2.imwrite(stringLoc, resized[i])

# %%
for i in range(len(resized)):
    stringLoc = './256x256_NormalizedWhaleImagesGray/' + images[i][29:] 
    image = resized[i]
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(stringLoc, gray)
